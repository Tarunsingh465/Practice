# %%
import cowsay
cowsay.cow('Good Moooooooorning!')
# Out:
#   ____________________
# | Good Moooooooorning! |
# ...
#                     \
#                      \
#                        ^__^
#                        (oo)\_______
#                        (__)\       )\/\
#                            ||----w |
#                            ||     ||

# %%
class Car:
    pass

audi=Car()
bmw=Car()

print(type(audi))
print(audi)
print(bmw)
# Out:
# <class '__main__.Car'>
# ...

# %%
class Dog:
    ## constructor
    def __init__(self,name,age):
        self.name=name
        self.age=age
dog1=Dog('Buddy',3)
print(dog1)
print(dog1.name)
print(dog1.age)
# Out:
# ...
# Buddy
# 3

# %%
class Myclass:
    x=5

# %%
p1=Myclass() # p1 is an object of the class Myclass()
print(p1.x)
# Out:
# 5

# %%
print(p1.x)
# Out:
# 5

# %%
del p1 # deleting a class

# %%
print(p1.x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 print(p1.x)
#
# NameError: name 'p1' is not defined

# %%
# same class can have multiple objects

p1=Myclass()
p2=Myclass()
p3=Myclass()

print(p1.x)
print(p2.x)
print(p3.x)
# Out:
# 5
# 5
# 5

# %%
class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    
    def greet(self):
        print(f"Hello, my name is {self.name}")

p1=Person('Tarun',21)
print(p1.name)
p1.greet()
# Out:
# Tarun
# Hello, my name is Tarun

# %%
class Car:
    def __init__(self,brand,model):
        self.brand=brand
        self.model=model
    def mycar(self):
        print(f'My car brand is {self.brand} and the model is {self.model}.')

c1=Car('Porche',911)
print(c1.brand)
print(c1.model)
c1.mycar()
# Out:
# Porche
# 911
# My car brand is Porche and the model is 911.

# %%
class Person:
    def __init__(self,name,age,city):
        self.name=name
        self.age=age
        self.city=city
        
p1=Person('Tarun',21,"Indore")

print(f'My name is {p1.name}, my age is {p1.age} and i live in {p1.city}.')
# Out:
# My name is Tarun, my age is 21 and i live in Indore.

# %%
class Person:
    def __init__(self,name,age=18):
        self.name=name
        self.age=age
p1=Person("Raj")
p2=Person('Tarun',21)
print(p1.name, p1.age)
print(p2.name, p2.age)
# Out:
# Raj 18
# Tarun 21

# %%
class Person:
    def __init__(self,name,age,city,country):
        self.name=name
        self.age=age
        self.city=city
        self.country=country

p1=Person('Tarun',21,'Indore','India')
print(p1.name)
print(p1.age)
print(p1.city)
print(p1.country)
print(f"Hey guys! My name is {p1.name}, i am {p1.age} years old and i live in {p1.city}, {p1.country}.")
# Out:
# Tarun
# 21
# Indore
# India
# Hey guys! My name is Tarun, i am 21 years old and i live in Indore, India.

# %%
class Person:
    def __init__(self,name):
        self.name=name
        
    def printname(self):
        print(self.name)
        
p1=Person("Ram")
p2=Person("Shyam")

p1.printname()
p2.printname()
# Out:
# Ram
# Shyam

# %%
class student:
    def __init__(meth,name,enrollment,code):
        meth.name=name
        meth.enrollment=enrollment
        meth.code=code
    def statement(meth):
        print(f"Student's name : {meth.name}, enrollment_no : {meth.enrollment} and code : {meth.code}")

s1=student('Tarun Singh','DS38',61996)
s1.statement()
# Out:
# Student's name : Tarun Singh, enrollment_no : DS38 and code : 61996

# %%
class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age

p1=Person('Tarun',20)
print(p1.age)
#
p1.age=21     # Modifying values
p1.name='Raj' # Modifying values
print(p1.age)
print(p1.name)
# Out:
# 20
# 21
# Raj

# %%
class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age

p1=Person('Tarun',20)

del p1.age
print(p1.name)
try:
    print(p1.age)
except Exception as e:
    print(e)
# Out:
# Tarun
# 'Person' object has no attribute 'age'

# %%
class People:
    species='Human_being'

    def __init__(self,nationality):
        self.nationality=nationality

p1=People('Indian')
p2=People('American')
p3=People('Japanese')

print(p1.species,'&', p2.species)
print(p1.nationality)
print(p2.nationality)
# Out:
# Human_being & Human_being
# Indian
# American

# %%
class Person:
    species='Human'
    def __init__(self,name,gender):
        self.name=name
        self.gender=gender

p1=Person('Tarun','Male')
p2=Person('Sakshi','Female')

print(f'This is a person of species: {p1.species}, name of this person: {p1.name} and the gender of this person is {p1.gender}.')
print(f'This is a person of species: {p2.species}, name of this person: {p2.name} and the gender of this person is {p2.gender}.')
# Out:
# This is a person of species: Human, name of this person: Tarun and the gender of this person is Male.
# This is a person of species: Human, name of this person: Sakshi and the gender of this person is Female.

# %%
class Person:
    lastname=""
    def __init__(self,name):
        self.name=name

p1=Person('Tarun')
p2=Person('Raj')
p3=Person('Ajay')

p1.lastname='Singh'
Person.lastname='Shamani'

print(p1.name,p1.lastname)
print(p2.name,p2.lastname)
print(p3.name,p3.lastname)
# Out:
# Tarun Singh
# Raj Shamani
# Ajay Shamani

# %%
class Person:
    def __init__(self,name):
        self.name=name

p1=Person('Tarun')

p1.age=21
p1.city='Indore'

print(f"My name is {p1.name}, I'm {p1.age} years old and I live in {p1.city}.")
# Out:
# My name is Tarun, I'm 21 years old and I live in Indore.

# %%
class Person:
    def __init__(self,name):
        self.name=name
    def greet(self):
        print("Hello, my name is "+self.name,"!")

p1=Person('Ram')
p1.greet()
# Out:
# Hello, my name is Ram !

# %%
class Calculator:
    def add(self,a,b):
        return a+b
    
    def multiply(self,a,b):
        return a*b
    
    def subtraction(self,a,b):
        return b-a
    
    def division(self,a,b):
        return b/a

calc=Calculator()
print(calc.add(5,3))
print(calc.multiply(5,3))
print(calc.subtraction(5,3))
print(calc.division(5,3))
# Out:
# 8
# 15
# -2
# 0.6

# %%
class Calculator:
    def __init__(self,a,b):
        self.a=a
        self.b=b
    def add(self):
        return self.a+self.b
    
    def multiply(self):
        return self.a*self.b
    
    def subtraction(self):
        return self.b-self.a
    
    def division(self):
        return self.b/self.a

calc=Calculator(5,3)
print(calc.add())
print(calc.multiply())
print(calc.subtraction())
print(calc.division())
# Out:
# 8
# 15
# -2
# 0.6

# %%
class Person:
    message=print('Have a good day!')
    def __init__(self,name,age):
         self.name=name
         self.age=age
         
    def celebrate_birthday(self):
        self.age+=1
        print(f'Happy birthday! You are now {self.age}')
    
p1=Person('Tarun',20)
# Person.message
p1.celebrate_birthday()
# Out:
# Have a good day!
# Happy birthday! You are now 21

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

p1 = Person("Emil", 36)
print(p1)

# %%
class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def __str__(self):
        return f"{self.name} ({self.age})"
p1=Person("Tarun",21)
print(p1)
# Out:
# Tarun (21)

# %%
class Student:
    def __init__(self,name,grade):
       self.name=name
       self.grade=grade
    def __str__(self):
        return f"{self.name}'s grade is {self.grade}."
s1=Student('Tarun','A1')
print(s1)
# Out:
# Tarun's grade is A1.

# %%
class Myclass:
    x=5
    def student(self,name,std):
        self.name=name
        self.std=std
    def __str__(self):
        return f'{self.name}, {self.std}'
p1=Myclass()
p1.student('Tarun',12)
print(p1)
print(p1.x)
# Out:
# Tarun, 12
# 5

# %%
class Myclass:
    print(f'Have a nice day!')
    def __init__(self,name,year):
        self.name=name
        self.year=year
    def greet(self):
        print(f'All the best {self.name} :)')
s1=Myclass('Tarun','Final year')
print(f'You are {s1.name}, {s1.year} student.')
s1.greet()
# Out:
# Have a nice day!
# You are Tarun, Final year student.
# All the best Tarun :)

# %%
# Methods with paramerters 

class Calculator:
    def add(self,a,b):
        return a+b
    def multiply(self,a,b):
        return a*b
calc=Calculator()
print(calc.add(5,3))
print(calc.multiply(4,7))
# Out:
# 8
# 28

# %%
# Methods that access object properties

from psutil import pid_exists


class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def greet(self):
        print(f'Your name is {self.name} and you are {self.age} years old.')
        
p1=Person('Tarun',21)
p1.greet()
print(p1.name,',', p1.age)
# Out:
# Your name is Tarun and you are 21 years old.
# Tarun , 21

# %%
class Student:
    def __init__(self,name,grade):
        self.name=name
        self.grade=grade
    def __str__(self):
        return f"{self.name}- {self.grade}"
p1=Student('Tarun','A1')
print(p1)
# Out:
# Tarun- A1

# %%
class Playlist:
    def __init__(self,name):
        self.name=name
        self.song=[]
        
    def add_song(self,song):
        self.song.append(song)
        print(f'Song Added: {song}')
        
    def remove_song(self,song):
        self.song.remove(song)
        print(f'Song removed: {song}')
        
    def show_song(self):
        print(f'Playlist: {self.name}')
        for song in self.song:
            print(f'-{song}')
            
my_playlist=Playlist('Always you')
my_playlist.add_song('Mere mehboob qayamat hogi')
my_playlist.add_song('Fly me to the moon')
my_playlist.add_song('Falling in Love with you')
my_playlist.add_song('Sapno ki rani kab aayegi tu')
my_playlist.add_song('Coca-cola tu.......')
my_playlist.remove_song('Coca-cola tu.......')
my_playlist.show_song()
# Out:
# Song Added: Mere mehboob qayamat hogi
# Song Added: Fly me to the moon
# Song Added: Falling in Love with you
# Song Added: Sapno ki rani kab aayegi tu
# Song Added: Coca-cola tu.......
# Song removed: Coca-cola tu.......
# Playlist: Always you
# -Mere mehboob qayamat hogi
# -Fly me to the moon
# -Falling in Love with you
# -Sapno ki rani kab aayegi tu

# %%
my_playlist.show_song()
# Out:
# Playlist: Always you
# -Mere mehboob qayamat hogi
# -Fly me to the moon
# -Falling in Love with you
# -Sapno ki rani kab aayegi tu

# %%
del my_playlist.remove_song
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 del my_playlist.remove_song
#
# AttributeError: 'Playlist' object has no attribute 'remove_song'
