# %%
import cowsay
cowsay.cow("Good Mooooooorning!")
# Out:
#   ___________________
# | Good Mooooooorning! |
# ...
#                    \
#                     \
#                       ^__^
#                       (oo)\_______
#                       (__)\       )\/\
#                           ||----w |
#                           ||     ||

# %%
mytuple=('apple','banana','orange')
myit=iter(mytuple)

print(next(myit))
print(next(myit))
print(next(myit))
# Out:
# apple
# banana
# orange
