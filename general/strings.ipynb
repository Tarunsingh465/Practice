# %%
import cowsay
cowsay.cow("Good Mooooooooooring!")
# Out:
#   _____________________
# | Good Mooooooooooring! |
# ...
#                      \
#                       \
#                         ^__^
#                         (oo)\_______
#                         (__)\       )\/\
#                             ||----w |
#                             ||     ||

# %%
txt=f'The price is 49 dollars'
print(txt)
# Out:
# The price is 49 dollars

# %%
price=59
txt=f'The price is ${price}.'
print(txt)
# Out:
# The price is $59.

# %%
price=59
print(f'The price is ${price}.')
# Out:
# The price is $59.

# %%
txt=f'The price is {price:.2f} dollars.'
print(txt)
# Out:
# The price is 59.00 dollars.

# %%
txt=f'The price is {12*11} dollars.'
print(txt)
# Out:
# The price is 132 dollars.

# %%
price=45
tax=0.15
txt=f'The price with tax is {price+(price*tax)} dollars.'
print(txt)
# Out:
# The price with tax is 51.75 dollars.

# %%
fruit='apple'
txt=f'I love {fruit.upper()}'
print(txt)
# Out:
# I love APPLE

# %%
def product(hours):
    return hours*98

txt=f'The train covers {product(12)}km.'
print(txt)
# Out:
# The train covers 1176km.

# %%
price=59000
txt=f'The price is {price:,} dollars'
print(txt)
# Out:
# The price is 59,000 dollars

# %%
price=49
txt='The price is {} dollars'
print(txt.format(price))
# Out:
# The price is 49 dollars

# %%
price=59
item_no=23
txt='The price of item_no- {} is {} dollars'
print(txt.format(item_no,price))
# Out:
# The price of item_no- 23 is 59 dollars

# %%
quantity=3
itemno=21
price=49
myorder='I want {0} pieces of item number {1} for {2:.2f} dollars'
print(myorder.format(quantity,itemno,price))
# Out:
# I want 3 pieces of item number 21 for 49.00 dollars

# %%
name = 'Tarun'
age=21

info = 'I am {0}, my age is {1}.'
print(info.format(name,age))
# Out:
# I am Tarun, my age is 21.

# %%
txt='I have a {carname}, {model} of {year} model.'
print(txt.format(carname='Porche',model=911,year=2005))
# Out:
# I have a Porche, 911 of 2005 model.
