# %%
print(bool("Hello"))
print(bool(15))
# Out:
# True
# True

# %%
x = "Hello"
y = 15

print(bool(x))
print(bool(y))
# Out:
# True
# True

# %%
bool(False)
bool(None)
bool(0)
bool("")
bool(())
bool([])
bool({})
# Out:
# False

# %%
t=6
t&=6
print(t)
# Out:
# 6

# %%
x=9
x|=3
x
# Out:
# 11

# %%
x = ["apple", "banana"]
y = ["apple", "banana"]
z = x

print(x is z)
print(x is y)
print(x == y)
# Out:
# True
# False
# True

# %%
print((6 + 3) - (6 + 3))
# Out:
# 0

# %%
age=int(input("Enter your age: "))
if age >=18:
    if age<=60 and age>=45:
        print("You are a sub-senior citizen")
    else:
        print("You are senior citizen")
elif age<=12:
    print("You are a kid")
else:
    print("You are a minor")
# Out:
# You are senior citizen

# %%
s=(1,2,3,4)
print(type(s))
# Out:
# <class 'tuple'>

# %%
t={1,2,3,4,5}
t.remove(4)
t
# Out:
# {1, 2, 3, 5}

# %%
t.pop()
t
# Out:
# {2, 3, 5}

# %%
for i in range(1,11):
    print(i)
    if i==5:
        break
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
f=34637463
e=float(f)
print(e)
# Out:
# 34637463.0
